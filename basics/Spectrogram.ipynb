# %%
# !wget https://google.github.io/tacotron/publications/tacotron2/demos/fox_question.wav

# %%
import torch
import torchaudio
import matplotlib.pyplot as plt

# %%
"""
Text : Does the quick brown fox jump over the lazy dog?
"""
file_name = 'fox_question.wav'
waveform, sample_rate = torchaudio.load(file_name)

# %%
specgram = torchaudio.transforms.Spectrogram()(waveform)

# %%
plt.figure(figsize=(10, 4))
plt.imshow(specgram.log2()[0,:,:].numpy())
plt.colorbar()
plt.title('SPETOGRAM')
plt.tight_layout()
plt.show()
